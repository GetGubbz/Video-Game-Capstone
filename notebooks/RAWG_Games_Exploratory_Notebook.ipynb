# %% [markdown]
# ## Capstone Notebook

# %%
import requests
import json
import pandas as pd
import os

# %%
with open('keys.json') as fi:
    credentials = json.load(fi)
api_key = credentials["games_url"]

# %%
response = requests.get(api_key)
response
# Out:
# <Response [200]>

# %%
res = response.json()

# %%
res.keys()
# Out:
# dict_keys(['count', 'next', 'previous', 'results', 'seo_title', 'seo_description', 'seo_keywords', 'seo_h1', 'noindex', 'nofollow', 'description', 'filters', 'nofollow_collections'])

# %%
games = pd.DataFrame(res['results'])
games.head(2)
# Out:
#      id                     slug                      name    released    tba  \
# 0  3498       grand-theft-auto-v        Grand Theft Auto V  2013-09-17  False
# 1  3328  the-witcher-3-wild-hunt  The Witcher 3: Wild Hunt  2015-05-18  False
#
#                                     background_image  rating  rating_top  \
# 0  https://media.rawg.io/media/games/20a/20aa03a1...    4.47           5
# 1  https://media.rawg.io/media/games/618/618c2031...    4.64           5
#
#                                              ratings  ratings_count  ...  \
# 0  [{'id': 5, 'title': 'exceptional', 'count': 42...           7117  ...
# 1  [{'id': 5, 'title': 'exceptional', 'count': 53...           6913  ...
#
#    saturated_color  dominant_color  \
# 0           0f0f0f          0f0f0f
# 1           0f0f0f          0f0f0f
#
#                                            platforms  \
# 0  [{'platform': {'id': 4, 'name': 'PC', 'slug': ...
# 1  [{'platform': {'id': 186, 'name': 'Xbox Series...
#
# ...

# %%
games.columns
# Out:
# Index(['id', 'slug', 'name', 'released', 'tba', 'background_image', 'rating',
#        'rating_top', 'ratings', 'ratings_count', 'reviews_text_count', 'added',
#        'added_by_status', 'metacritic', 'playtime', 'suggestions_count',
#        'updated', 'user_game', 'reviews_count', 'saturated_color',
#        'dominant_color', 'platforms', 'parent_platforms', 'genres', 'stores',
#        'clip', 'tags', 'esrb_rating', 'short_screenshots'],
#       dtype='object')

# %%
games = games.drop(columns=['tba', 'background_image', 'saturated_color', 'dominant_color', 'short_screenshots'])
games.head()
# Out:
#      id                             slug                              name  \
# 0  3498               grand-theft-auto-v                Grand Theft Auto V
# 1  3328          the-witcher-3-wild-hunt          The Witcher 3: Wild Hunt
# 2  4200                         portal-2                          Portal 2
# 3  4291  counter-strike-global-offensive  Counter-Strike: Global Offensive
# 4  5286                      tomb-raider                Tomb Raider (2013)
#
#      released  rating  rating_top  \
# 0  2013-09-17    4.47           5
# 1  2015-05-18    4.64           5
# 2  2011-04-18    4.59           5
# 3  2012-08-21    3.57           4
# 4  2013-03-05    4.06           4
#
#                                              ratings  ratings_count  \
# 0  [{'id': 5, 'title': 'exceptional', 'count': 42...           7117
# 1  [{'id': 5, 'title': 'exceptional', 'count': 53...           6913
# 2  [{'id': 5, 'title': 'exceptional', 'count': 41...           5906
# ...

# %%
games.shape
# Out:
# (20, 24)
